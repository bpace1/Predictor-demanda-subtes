# %% [markdown]
# # Etapa 1 – Exploración visual de los datos (EDA)
# En esta etapa se realizará un análisis descriptivo inicial del dataset, con el objetivo de comprender su estructura y detectar patrones relevantes.
#
# Se utilizarán técnicas de visualización y estadística descriptiva para:
#
# Explorar diferencias entre líneas y estaciones.
#
# *   Analizar la evolución temporal del flujo de pasajeros.
# *   Identificar estacionalidades (diarias, semanales, mensuales).
# *   Evaluar correlaciones entre variables (por ejemplo, tarifa vs pasajeros).
#
#
# **Este análisis permitirá generar primeras intuiciones sobre la hipótesis planteada.**

# %% [markdown]
# ## 1.1 Instalación, descarga de datos e importación de librerías.
#
# En esta celda se instala y actualiza la librería `gdown`, que permite descargar archivos desde Google Drive.
#
# Luego se verifica si la carpeta `Subtes` ya está disponible en el entorno de trabajo; en caso contrario, se descarga desde el enlace correspondiente.
#
#
# También se importan las librerías principales utilizadas en el análisis: `pandas` para manipulación de datos, `plotly` para visualizaciones interactivas y `statsmodels` para análisis estadístico.

# %%
# !pip install --upgrade gdown -q

import os

if "Subtes" not in os.listdir():
    # !gdown --folder https://drive.google.com/drive/folders/1N_upx66kxNa6MqUD40SsvJqioQLJ8jdm
else:
    print("La carpeta 'Subtes' ya está descargada.")


import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
# Out:
# Retrieving folder contents
# Processing file 10lQcR4B-Qs9a5AbFBf8PzLUOoqqVPxQy BaseUnificadaEstaciones.csv
# Processing file 1V6Cjhf2QU_gcig6HT5EvXhk0n2Egerqr estaciones-accesibles.csv
# Processing file 1CyWPBgfAYRBcYvQO7U7cRlAoQbGWoosP historico_2014.csv
# Processing file 1g7LpNJFqNcqDmgaGc81MMgV3VfrD6Ah6 historico_2015.csv
# Processing file 1QqOb3oLoMs014d2YBYw4_e8ww4jo-JX1 historico_2016.csv
# Processing file 1G7noINplTWyt2g9xRrS7l0BKgFOW05hv historico_2017.csv
# Processing file 11WgJxZsC4zUURSlCUBEQKXCQK5RLkRNZ historico_2018.csv
# Processing file 1DVgvubSgYCTPQCfA4zj5eiH_ni136o9A historico_2019.csv
# Processing file 1hlfAVsJS20InzvIkUXT4t5_nOgd2m1NW historico_2020.csv
# Processing file 1hW4qHioTzrXlDnBfWextpMQpar0kmL03 historico_2021.csv
# Processing file 1sWI3jP6f9VDJ-IE1EI1lkc8rkxooP3b7 lineas-de-subte.csv
# Processing file 1yETNbct23DLqYoN7ti6hNV3RdKErwMYI registro-historico-del-precio-del-boleto.csv
# ...

# %% [markdown]
# ## 1.2. Verificación de archivos disponibles en el entorno

# %%
print("Archivos y carpetas en Colab:")
print(os.listdir('.'))
# Out:
# Archivos y carpetas en Colab:
# ['.config', 'Subtes', 'sample_data']

# %% [markdown]
# ## 1.3. Definición de la ruta de trabajo
# En esta celda se define la variable `path`, que contiene la ubicación de la carpeta donde se encuentran los archivos del dataset. Esto permite reutilizar la ruta de forma más simple al cargar los distintos archivos CSV.

# %%
path = "Subtes/"

# %% [markdown]
# ## 1.4. Carga de datasets principales
# En esta celda se cargan dos datasets principales:
# - `registro-historico-del-precio-del-boleto.csv`: contiene la evolución histórica del precio del boleto.
# - `viajes_anual.csv`: contiene la cantidad anual de viajes por línea de subte.
# Luego se imprimen las dimensiones de cada dataset para verificar que la carga se haya realizado correctamente.

# %%
# Cargar los datasets que definimos previamente
df_historico_precio = pd.read_csv(path + 'registro-historico-del-precio-del-boleto.csv')
df_viajes_anual = pd.read_csv(path + 'viajes_anual.csv')

# Verificar que se hayan cargado correctamente
print("Precios cargados:", df_historico_precio.shape)
print("Viajes anuales cargados:", df_viajes_anual.shape)
# Out:
# Precios cargados: (304, 4)
# Viajes anuales cargados: (48, 3)

# %% [markdown]
# ## 1.5. Inspección inicial de los datasets
# Esta celda permite observar la estructura básica de los datos cargados.
#
# Se muestran las primeras filas de cada dataset y se obtiene información sobre columnas, tipos de datos, cantidad de registros y valores no nulos.
#
# Esta inspección inicial es importante para comprender qué variables están disponibles y detectar posibles necesidades de limpieza o transformación.
# Celda 6

# %%
# Inspección básica para ver la estructura con tus variables
print("--- Histórico Precio del Boleto ---")
display(df_historico_precio.head())
print(df_historico_precio.info())

print("\n--- Viajes Anuales ---")
display(df_viajes_anual.head())
print(df_viajes_anual.info())
# Out:
# --- Histórico Precio del Boleto ---
#     año  mes_numero      mes  precio
# 0  1994           1    ENERO    0.45
# 1  1994           2  FEBRERO    0.45
# 2  1994           3    MARZO    0.45
# 3  1994           4    ABRIL    0.45
# 4  1994           5     MAYO    0.45
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   año         304 non-null    int64
#  1   mes_numero  304 non-null    int64
#  2   mes         304 non-null    object
#  3   precio      304 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 9.6+ KB
# None
#
# --- Viajes Anuales ---
#    year LINEA     total
# 0  2013     A  26731478
# 1  2013     B  49458167
# 2  2013     C  27839180
# 3  2013     D  45532347
# 4  2013     E  11815541
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
# ...

# %% [markdown]
# ## 1.6. Preparación temporal del dataset de precios
# En esta celda se crea una columna de fecha a partir del año y el número de mes del dataset de precios.
#
# Esto permite trabajar la tarifa como una serie temporal.
#
# Además, se calcula el precio promedio anual del boleto, agrupando los registros mensuales por año.
#
# Este valor será utilizado luego para cruzar la evolución tarifaria con la cantidad anual de pasajeros.

# %%
# Para el dataset de precios: crear una columna de fecha para series de tiempo
df_historico_precio['fecha'] = pd.to_datetime(df_historico_precio['año'].astype(str) + '-' + df_historico_precio['mes_numero'].astype(str) + '-01')

# Calcular el precio promedio anual del boleto para cruzar con los viajes anuales
precio_anual = df_historico_precio.groupby('año')['precio'].mean().reset_index()

# %% [markdown]
# ## 1.7. Visualización de la tabla de precio promedio anual
# Esta celda muestra el dataset `precio_anual`, que resume el precio promedio del boleto para cada año disponible.
# Esta tabla permite observar la evolución general de la tarifa antes de pasar a una visualización gráfica.

# %%
precio_anual
# Out:
#      año     precio
# 0   1994   0.450000
# 1   1995   0.450000
# 2   1996   0.462500
# 3   1997   0.500000
# 4   1998   0.500000
# 5   1999   0.566667
# 6   2000   0.600000
# 7   2001   0.683333
# 8   2002   0.700000
# 9   2003   0.700000
# 10  2004   0.700000
# 11  2005   0.700000
# 12  2006   0.700000
# 13  2007   0.700000
# 14  2008   0.900000
# 15  2009   1.100000
# 16  2010   1.100000
# 17  2011   1.100000
# 18  2012   2.500000
# 19  2013   2.666667
# 20  2014   4.333333
# 21  2015   4.500000
# 22  2016   5.000000
# 23  2017   7.500000
# 24  2018   9.833333
# 25  2019  16.875000

# %% [markdown]
# ## 1.8. Evolución histórica del precio del boleto
# En esta celda se construye un gráfico de líneas que muestra la evolución mensual del precio del boleto a lo largo del tiempo.
# El objetivo es identificar períodos de estabilidad tarifaria, aumentos progresivos y posibles saltos relevantes en el precio del pasaje.

# %%
fig_precio = px.line(
    df_historico_precio,
    x='fecha',
    y='precio',
    title='Evolución Histórica del Precio del Boleto',
    labels={'precio': 'Precio ($)', 'fecha': 'Fecha'},
    markers=True
)
fig_precio.update_layout(template='plotly_white')
fig_precio.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 1.9. Revisión de columnas del dataset de viajes anuales
# Esta celda muestra los nombres de las columnas del dataset de viajes anuales. Sirve para confirmar cómo están nombradas las variables antes de realizar transformaciones, agrupamientos o visualizaciones.

# %%
df_viajes_anual.columns
# Out:
# Index(['año', 'LINEA', 'total'], dtype='object')

# %% [markdown]
# ## 1.10. Evolución anual de pasajeros por línea
# En esta celda se renombra la columna de año y se genera un gráfico de líneas que muestra la cantidad anual de viajes para cada línea de subte.
# Este análisis permite comparar la evolución de la demanda entre líneas e identificar diferencias en volumen de pasajeros, tendencias de crecimiento o caídas relevantes.

# %%
df_viajes_anual = df_viajes_anual.rename(columns={'year': 'año'})

fig_viajes = px.line(
    df_viajes_anual,
    x='año',
    y='total',
    color='LINEA',
    title='Cantidad Anual de Viajes por Línea',
    labels={'total': 'Total de Viajes', 'año': 'Año'},
    markers=True
)
# Ajustar el eje X para que muestre solo años enteros
fig_viajes.update_xaxes(dtick=1)
fig_viajes.update_layout(template='plotly_white')
fig_viajes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 1.11. Relación visual entre viajes totales y precio promedio anual
# En esta celda se agrupan los viajes anuales de todas las líneas para obtener el total de pasajeros por año. Luego se cruza esta información con el precio promedio anual del boleto.
# El gráfico resultante utiliza dos ejes: uno para representar la cantidad total de viajes y otro para representar el precio promedio del boleto. Esto permite observar visualmente si existen patrones comunes entre aumentos tarifarios y cambios en la demanda.

# %%
# Sumar todos los viajes de todas las líneas por año
viajes_totales_anuales = df_viajes_anual.groupby('año')['total'].sum().reset_index()

# Unir con el precio anual promedio que calculamos en el Paso 2
df_cruzado = pd.merge(viajes_totales_anuales, precio_anual, on='año', how='inner')

# Crear el gráfico de doble eje Y
fig_cruce = go.Figure()

# Agregar barra para los viajes totales
fig_cruce.add_trace(
    go.Bar(x=df_cruzado['año'], y=df_cruzado['total'], name='Total de Viajes', opacity=0.6)
)

# Agregar línea para el precio promedio
fig_cruce.add_trace(
    go.Scatter(x=df_cruzado['año'], y=df_cruzado['precio'], name='Precio Promedio', yaxis='y2', mode='lines+markers', line=dict(color='red', width=3))
)

# Configurar el diseño
fig_cruce.update_layout(
    title='Relación entre Viajes Totales y Precio Promedio Anual del Boleto',
    xaxis=dict(title='Año', dtick=1),
    yaxis=dict(title='Total de Viajes', side='left'),
    yaxis2=dict(title='Precio Promedio ($)', side='right', overlaying='y', showgrid=False),
    template='plotly_white',
    legend=dict(x=0.01, y=0.99) # Posición de la leyenda
)

fig_cruce.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 1.12. Primer análisis estadístico: causalidad de Granger entre tarifa y demanda
# En esta celda se prepara una serie temporal anual con el total de viajes y el precio promedio del boleto. Luego se aplica una diferenciación para reducir tendencias y se ejecuta un test de causalidad de Granger.
# El objetivo es explorar si los cambios en el precio podrían ayudar a anticipar cambios en la cantidad total de viajes. Sin embargo, este análisis debe interpretarse con cautela porque la cantidad de observaciones disponibles es reducida.

# %%
# 1. Homogeneizar columnas
# Aseguramos que la columna de tiempo se llame 'año' en ambos
if 'year' in df_viajes_anual.columns:
    df_viajes_anual = df_viajes_anual.rename(columns={'year': 'año'})

# 2. Agrupación y unificación
# Sumamos el total de viajes de todas las líneas por año
viajes_totales = df_viajes_anual.groupby('año')['total'].sum().reset_index()

# Calculamos el precio promedio del boleto por año
precio_promedio = df_historico_precio.groupby('año')['precio'].mean().reset_index()

# Unimos ambos DataFrames
df_granger = pd.merge(viajes_totales, precio_promedio, on='año', how='inner')

# 3. Preparación de la Serie Temporal
# Ordenamos cronológicamente y seteamos el año como índice del DataFrame
df_granger = df_granger.sort_values('año').set_index('año')

# 4. Estacionariedad
# Aplicamos diferenciación (valor actual menos valor anterior) para eliminar tendencias
df_estacionario = df_granger[['total', 'precio']].diff().dropna()

# 5. Ejecución del Test de Granger
# El formato requiere que la columna 1 sea Y (lo que queremos predecir: total de viajes)
# y la columna 2 sea X (la variable causal: precio)
datos_test = df_estacionario[['total', 'precio']]

print("--- Muestra de la Serie Temporal Unificada ---")
display(df_granger.head())

print("\n--- Resultados del Test de Causalidad de Granger ---")
print("H0: El 'precio' NO causa a 'total' de viajes\n")

# NOTA: Usamos maxlag=1 o 2 (rezagos de 1 o 2 años).
# Al ser datos anuales, usar un número mayor romperá el test por falta de observaciones.
try:
    resultados = grangercausalitytests(datos_test, maxlag=2, verbose=True)
except ValueError as e:
    print(f"\n⚠️ Error de modelado: {e}")
    print("Esto suele ocurrir si hay muy pocos años en el dataset para calcular múltiples rezagos.")
    print("Intentando nuevamente solo con maxlag=1...\n")
    resultados = grangercausalitytests(datos_test, maxlag=1, verbose=True)
# Out:
# --- Muestra de la Serie Temporal Unificada ---
#           total    precio
# año
# 2013  165754193  2.666667
# 2014  255189625  4.333333
# 2015  282519120  4.500000
# 2016  314418191  5.000000
# 2017  328701725  7.500000
# --- Resultados del Test de Causalidad de Granger ---
# H0: El 'precio' NO causa a 'total' de viajes
#
#
# ⚠️ Error de modelado: Insufficient observations. Maximum allowable lag is 0
# Esto suele ocurrir si hay muy pocos años en el dataset para calcular múltiples rezagos.
# Intentando nuevamente solo con maxlag=1...
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7566  , p=0.4761  , df_denom=2, df_num=1
# ssr based chi2 test:   chi2=1.8915  , p=0.1690  , df=1
# likelihood ratio test: chi2=1.6042  , p=0.2053  , df=1
# parameter F test:         F=0.7566  , p=0.4761  , df_denom=2, df_num=1
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/stattools.py:1556: FutureWarning:
#
# ...

# %% [markdown]
# ## 1.13. Consolidación mensual de viajes desde archivos históricos
# En esta celda se procesan los archivos históricos masivos de viajes utilizando `DuckDB`. Se leen los archivos `historico_*.csv`, se agrupan los registros por fecha y se calcula el total de pasajeros.
# Luego se corrigen y transforman las fechas, extrayendo año y mes, para construir un dataset mensual consolidado. Este dataset será clave para analizar la evolución mensual de la demanda y detectar patrones de estacionalidad.
# Texto breve para cerrar la sección actual

# %%
import duckdb
import pandas as pd

print("Procesando los archivos masivos ignorando problemas de fechas en CSV...")

# 1. Le decimos a DuckDB que lea todo como VARCHAR (texto) para evitar que se rompa con fechas raras.
# 2. Agrupamos por año y mes como texto.
query_mensual = """
    SELECT
        COALESCE(fecha, FECHA) AS fecha_texto,
        SUM(CAST(COALESCE(pax_total, PAX_TOTAL) AS INT)) AS total_viajes
    FROM read_csv_auto('Subtes/historico_*.csv', union_by_name=True, all_varchar=True)
    GROUP BY 1
"""

# Ejecutamos la consulta. Ahora devolverá un DataFrame con 'fecha_texto' y 'total_viajes'
df_temp = duckdb.query(query_mensual).df()

# Filtramos filas vacías
df_temp = df_temp.dropna(subset=['fecha_texto'])

print("Aplicando magia de Pandas para arreglar las fechas (esto puede tardar unos segundos)...")

# 3. Dejamos que Pandas intente adivinar el formato de fecha (es experto en esto)
df_temp['fecha_real'] = pd.to_datetime(df_temp['fecha_texto'], format='mixed', dayfirst=True, errors='coerce')

# 4. Ahora sí, extraemos el año y mes numérico limpio
df_temp['año'] = df_temp['fecha_real'].dt.year
df_temp['mes_numero'] = df_temp['fecha_real'].dt.month

# 5. Volvemos a agrupar todo por mes (porque el día ya no nos importa)
df_viajes_mensual = df_temp.groupby(['año', 'mes_numero'])['total_viajes'].sum().reset_index()

# Limpiamos los nulos por las dudas y convertimos a entero
df_viajes_mensual = df_viajes_mensual.dropna()
df_viajes_mensual['año'] = df_viajes_mensual['año'].astype(int)
df_viajes_mensual['mes_numero'] = df_viajes_mensual['mes_numero'].astype(int)

# Ordenamos cronológicamente
df_viajes_mensual = df_viajes_mensual.sort_values(['año', 'mes_numero']).reset_index(drop=True)

print("¡Dataset mensual consolidado y limpio!")
display(df_viajes_mensual.head())
# Out:
# Procesando los archivos masivos ignorando problemas de fechas en CSV...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Aplicando magia de Pandas para arreglar las fechas (esto puede tardar unos segundos)...
# ¡Dataset mensual consolidado y limpio!
#     año  mes_numero  total_viajes
# 0  2014           1    17080258.0
# 1  2014           2    18068193.0
# 2  2014           3    20689889.0
# 3  2014           4    21366758.0
# 4  2014           5    22648413.0

# %% [markdown]
# ## 1.14 Avance del EDA
# Hasta este punto, el análisis exploratorio permite comprender la estructura inicial de los datasets, observar la evolución histórica del precio del boleto, comparar la cantidad anual de pasajeros entre líneas y comenzar a estudiar la relación entre tarifa y demanda.
# Sin embargo, para completar la etapa de EDA todavía será necesario profundizar el
#
# *   análisis mensual, semanal, diario, por estación y por línea,
# *   incorporar correlaciones e interpretaciones visuales más detalladas.

# %% [markdown]
# # Etapa 2 – Limpieza y transformación

# %% [markdown]
# ## 2.1 Tratamiento de valores faltantes (imputación o eliminación).

# %% [markdown]
# ## 2.2 Detección y manejo de outliers.

# %% [markdown]
# ## 2.3 Transformación de variables (por ejemplo, fechas a variables temporales como día de semana).

# %% [markdown]
# ## 2.4 Normalización o estandarización de variables numéricas.

# %% [markdown]
# ## 2.5 Nuevas variables derivadas, como indicadores de tarifa, períodos pre y post aumentos, o agrupaciones por franjas horarias.

# %% [markdown]
#  # Etapa 3 – Modelado con Machine Learning

# %% [markdown]
# ## 3.1 Regresión lineal múltiple

# %% [markdown]
# ## 3.2 ARIMA/SARIMA:

# %% [markdown]
# ## 3.3 AE, RMSE y R² ajustado.
